# %% [markdown]
# <a href="https://colab.research.google.com/github/FridrichMethod/MPNN/blob/main/mpnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MPNN
#
# > CS224W final project
